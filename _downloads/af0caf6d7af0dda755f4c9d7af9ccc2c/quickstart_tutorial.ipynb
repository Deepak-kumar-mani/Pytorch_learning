# %%
# For tips on running notebooks in Google Colab, see
# https://docs.pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %%
# !nvidia-smi
# Out:
# Sun Jul 26 15:29:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# [Learn the Basics](intro.html) \|\| **Quickstart** \|\|
# [Tensors](tensorqs_tutorial.html) \|\| [Datasets &
# DataLoaders](data_tutorial.html) \|\|
# [Transforms](transforms_tutorial.html) \|\| [Build
# Model](buildmodel_tutorial.html) \|\|
# [Autograd](autogradqs_tutorial.html) \|\|
# [Optimization](optimization_tutorial.html) \|\| [Save & Load
# Model](saveloadrun_tutorial.html)
#
# Quickstart
# ==========
#
# This section runs through the API for common tasks in machine learning.
# Refer to the links in each section to dive deeper.
#
# Working with data
# -----------------
#
# PyTorch has two [primitives to work with
# data](https://pytorch.org/docs/stable/data.html):
# `torch.utils.data.DataLoader` and `torch.utils.data.Dataset`. `Dataset`
# stores the samples and their corresponding labels, and `DataLoader`
# wraps an iterable around the `Dataset`.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import v2   ## transformations we can considers as resizing from 32X32 pixcel to 20X20 pixcel

# %% [markdown]
# PyTorch offers domain-specific libraries such as
# [TorchText](https://pytorch.org/text/stable/index.html),
# [TorchVision](https://pytorch.org/vision/stable/index.html), and
# [TorchAudio](https://pytorch.org/audio/stable/index.html), all of which
# include datasets. For this tutorial, we will be using a TorchVision
# dataset.
#
# The `torchvision.datasets` module contains `Dataset` objects for many
# real-world vision data like CIFAR, COCO ([full list
# here](https://pytorch.org/vision/stable/datasets.html)). In this
# tutorial, we use the FashionMNIST dataset. Every TorchVision `Dataset`
# includes two arguments: `transform` and `target_transform` to modify the
# samples and labels respectively.

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)]),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)]),
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 10.6MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 165kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.18MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 11.8MB/s]

# %% [markdown]
# We pass the `Dataset` as an argument to `DataLoader`. This wraps an
# iterable over our dataset, and supports automatic batching, sampling,
# shuffling and multiprocess data loading. Here we define a batch size of
# 64, i.e. each element in the dataloader iterable will return a batch of
# 64 features and labels.

# %%
len(training_data)
# Out:
# 60000

# %%
len(test_data)
# Out:
# 10000

# %%
batch_size = 64   ## this need to be updated based on the hardware availability (formula is 2^n), this is an hyperparameter as well

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break

"""
## output
## Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28]) here
# N(batch size) is 64,
# C(channel which is RGB 1 means cromo or black n white) is 1,
# H(height)-28,
# W(width)-28
# this shape representation can be changed/reorderd

## Shape of y: torch.Size([64]) torch.int64

"""
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64
# '\n## output\n## Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28]) here \n# N(batch size) is 64, \n# C(channel which is RGB 1 means cromo or black n white) is 1, \n# H(height)-28, \n# W(width)-28 \n# this shape representation can be changed/reorderd  \n\n## Shape of y: torch.Size([64]) torch.int64\n\n'

# %% [markdown]
# Read more about [loading data in PyTorch](data_tutorial.html).

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# Creating Models
# ===============
#
# To define a neural network in PyTorch, we create a class that inherits
# from
# [nn.Module](https://pytorch.org/docs/stable/generated/torch.nn.Module.html).
# We define the layers of the network in the `__init__` function and
# specify how data will pass through the network in the `forward`
# function. To accelerate operations in the neural network, we move it to
# the
# [accelerator](https://pytorch.org/docs/stable/torch.html#accelerators)
# such as CUDA, MPS, MTIA, or XPU. If the current accelerator is
# available, we will use it. Otherwise, we use the CPU.

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# # Flatten - (30, 30, 3) ----> (2700)
#
# # Linear means Hidden/Fully connected/Dense
#
# first we flatten the data then feed it to
#
# convert -----> flatten -----> Linear
#
# # Activation function (to perform orr to introduce non linearity opration)
# Relu
#
# max(0,1)
#
#
# # Sequential
# nn ---- Seuential Model-----> then by Layer by Layer stacking

# %%
# Define model
class NeuralNetwork(nn.Module):   ## inherited nural network module
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()  ##converting the dimension ex: flatten-(30,30,2)  --> multiple the dimensions 30*30*3 = (2700)
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),   ## fully connected layer 28X8 is input shape and 512 is number of neurons
            nn.ReLU(),               ## this i an activation function
            nn.Linear(512, 512),     ## Tansformation layer here we get 512 input from last layer and we are giving 512 output in this layer
            nn.ReLU(),               ## this is an activation function
            nn.Linear(512, 10)       ## Transformation layer here we get 512 input from last layer and my final output is only 10 dimension/class/varity of outputs
        )

    def forward(self, x):            ## creating forward operation taking x as input
        x = self.flatten(x)          ## calling the inital flatten operation, here all my inputs in single operation
        logits = self.linear_relu_stack(x)  ## calling the inital stack operation is performed
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Read more about [building neural networks in
# PyTorch](buildmodel_tutorial.html).

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# Optimizing the Model Parameters
# ===============================
#
# To train a model, we need a [loss
# function](https://pytorch.org/docs/stable/nn.html#loss-functions) and an
# [optimizer](https://pytorch.org/docs/stable/optim.html).

# %%
loss_fn = nn.CrossEntropyLoss()    ## we can use any loss function
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)  # SGD - Gradient decent   &   Lr -

# %% [markdown]
# In a single training loop, the model makes predictions on the training
# dataset (fed to it in batches), and backpropagates the prediction error
# to adjust the model\'s parameters.

# %%
def train(dataloader, model, loss_fn, optimizer):   ## we need these 4 arguments to train a dataset
    size = len(dataloader.dataset)                  ## getting the dataset size
    model.train()                                   ## in train we need to change the model to train
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)           ## loading the data into CUDA

        # Compute prediction error
        pred = model(X)                             ## Predection starts
        loss = loss_fn(pred, y)                     ## calculating the loss here Y- is my actuals

        # Backpropagation
        loss.backward()                             ## upating the weights using backwar pass to update the weight and biase based on the loss
        optimizer.step()                            ## Optimizer help to reach us global minima
        optimizer.zero_grad()                       ## in derivative we need zero_grad to apply the chain rule

        if batch % 100 == 0:                        ## here the loss will be calculated based on a perticular batch
            loss, current = loss.item(), (batch + 1) * len(X)   ## here we are incresing the batch
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %% [markdown]
# We also check the model\'s performance against the test dataset to
# ensure it is learning.

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()                                  ## in test we need to change the model to evaluation
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()     ## calculating the test loss
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()   ## argmax returns max indices/index
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# The training process is conducted over several iterations (*epochs*).
# During each epoch, the model learns parameters to make better
# predictions. We print the model\'s accuracy and loss at each epoch;
# we\'d like to see the accuracy increase and the loss decrease with every
# epoch.

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.303894  [   64/60000]
# loss: 2.297827  [ 6464/60000]
# loss: 2.272934  [12864/60000]
# loss: 2.265964  [19264/60000]
# loss: 2.250070  [25664/60000]
# loss: 2.232519  [32064/60000]
# loss: 2.229575  [38464/60000]
# loss: 2.206968  [44864/60000]
# loss: 2.193162  [51264/60000]
# loss: 2.171515  [57664/60000]
# Test Error:
#  Accuracy: 47.4%, Avg loss: 2.158664
#
# Epoch 2
# -------------------------------
# loss: 2.166259  [   64/60000]
# loss: 2.162871  [ 6464/60000]
# loss: 2.101306  [12864/60000]
# loss: 2.118578  [19264/60000]
# loss: 2.063071  [25664/60000]
# loss: 2.016305  [32064/60000]
# loss: 2.033720  [38464/60000]
# loss: 1.965288  [44864/60000]
# loss: 1.960453  [51264/60000]
# loss: 1.904485  [57664/60000]
# Test Error:
#  Accuracy: 53.1%, Avg loss: 1.887088
#
# Epoch 3
# -------------------------------
# loss: 1.917522  [   64/60000]
# loss: 1.894415  [ 6464/60000]
# loss: 1.772082  [12864/60000]
# ...

# %% [markdown]
# Read more about [Training your model](optimization_tutorial.html).

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# Saving Models
# =============
#
# A common way to save a model is to serialize the internal state
# dictionary (containing the model parameters).

# %% [markdown]
# After training we need to save the model, so thhat in future we can load it later

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# Loading Models
# ==============
#
# The process for loading a model includes re-creating the model structure
# and loading the state dictionary into it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_617/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
## Loading the saved model

model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# This model can now be used to make predictions.

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    x = x.to(device)
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "Ankle boot", Actual: "Ankle boot"

# %% [markdown]
# Read more about [Saving & Loading your
# model](saveloadrun_tutorial.html).
